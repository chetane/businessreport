# %% [markdown]
# <a href="https://colab.research.google.com/github/chetane/businessreport/blob/main/Development_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Enron Email Analysis - Development Notebook
#
# > Student Name: Sookdeb Chetane
#
# > Student ID: 20918918
#
# > Lecturer Name: Ramchurn Navishna
#
# > Workshop Time: Monday, 13:40 - 15:50

# %% [markdown]
# #Pseudocode

# %% [markdown]
# ##Downloading Enron Dataset

# %% [markdown]
# Set enron.db to the content downloaded from the URL "https://curtin-my.sharepoint.com/:u:/g/personal/211934g_curtin_edu_au/EaYagsqa2r1Bi5wtHbswGFwBH2kd2uTnz6rlka7GI36GUQ?download=1"

# %% [markdown]
# ##Importing Modules and Connecting Database

# %% [markdown]
# 1. Start
# 2. Connect to the "enron.db" SQLite database
# 3. Import Modules as sqlite3, pandas, seaborn, matplotlib, ipywidgets and numpy

# %% [markdown]
# ##Check Schema of Database and Tables

# %% [markdown]
# 4. Retrieve the list of table names from the database
# 5. Retrieve the columns of the "employeelist" table
# 6. Retrieve the columns of the "message" table
# 7. Retrieve the columns of the "recipientinfo" table
# 8. Retrieve the columns of the "referenceinfo" table
# 9. Execute the SQL query to select all records from the "employeelist" table
# 10. Store the result in the "employeelist_df" DataFrame
# 11. Execute the SQL query to select all records from the "message" table
# 12. Store the result in the "message_df" DataFrame
# 13. Execute the SQL query to select all records from the "recipientinfo" table
# 14. Store the result in the "recipientinfo_df" DataFrame
# 15. Execute the SQL query to select all records from the "referenceinfo" table
# 16. Store the result in the "referenceinfo_df" DataFrame
# 17. Execute the SQL query to select the "date" column from the "message" table
# 18. Store the result in the "message_df" DataFrame
# 19. Execute the SQL query to count the number of messages per day and group by date
# 20. Store the result in the "msgperday_df" DataFrame

# %% [markdown]
# ##Visualizations

# %% [markdown]
# ###Email Traffic Overtime

# %% [markdown]
# 21. Create a line plot with x-axis as "date" and y-axis as "count" from "msgperday_df"
# 22. Execute the SQL query to count the number of messages per week and group by date
# 23. Store the result in the "msgperweek_df" DataFrame
# 24. Create a line plot with x-axis as "date" and y-axis as "count" from "msgperweek_df"
# 25. Execute the SQL query to count the number of messages per month and group by date
# 26. Store the result in the "msgpermonth_df" DataFrame
# 27. Create a line plot with x-axis as "date" and y-axis as "count" from "msgpermonth_df"

# %% [markdown]
# ###Top Senders and Recipients

# %% [markdown]
# 28. Execute the SQL query to retrieve the top 10 senders and their message counts
# 29. Store the result in the "top_sender_df" DataFrame
# 30. Create a bar plot with x-axis as "count" and y-axis as "sender" from "top_sender_df"
# 31. Display the bar plot
# 32. Execute the SQL query to retrieve the top 20 recipients and their message counts
# 33. Store the result in the "top_recipient_df" DataFrame
# 34. Create a bar plot with x-axis as "count" and y-axis as "recipient" from "top_recipient_df"
# 35. Display the bar plot

# %% [markdown]
# ###Email Distribution by Recipient Type

# %% [markdown]
# 36. Execute the SQL query to retrieve the distribution of recipient types and their counts
# 37. Store the result in the "recipient_df" DataFrame
# 38. Create a pie chart with labels as "rtype" and values as "count" from "recipient_df"
# 39. Set the title of the pie chart as "Distribution of Recipient Types"
# 40. Display the pie chart
# 41. End

# %% [markdown]
# #Testing

# %% [markdown]
# ###Syntax Error

# %% [markdown]
# **Appendix 1**
# ![Screenshot 2023-05-23 222052.png](data:image/png;base64,...)

# %% [markdown]
# **Type of error?** While writing my codes, I encountered some silly errors that were quite easily avoidable. However, we learn from our mistakes. Appendix 1 shows one of the many syntax errors I encountered during the testing phase.
#
# **Where is the error?** As seen in Appendix 1, I forgot to close the double inverted quotes, which later led to an error in the program.
#
# **How did I overcome it?** It was quite easy to spot this error, I ran my eyes through the codes many times, and I was able to spot it and mitigate it.

# %% [markdown]
# ###Name Error

# %% [markdown]
# **Appendix 2**
# ![Screenshot 2023-05-23 222137.png](data:image/png;base64,...)

# %% [markdown]
# **Type of error?** Name Error is something I encountered a lot during the testing phase. Appendix 2 shows a sample of one Name error I encountered during my testing phase.
#
# **Where is the error?** Appendix 2 shows that I made a typo while writing the code. Here I wrote "employeelist_d" instead of "employeelist_df" which caused an error as "employeelist_d" is not defined as a variable.
#
# **How did I overcome it?** This mistake was quite easy to correct as when you test it, the error display hence, you know exactly where you make a mistake.

# %% [markdown]
# ###Operational Error

# %% [markdown]
# **Appendix 3**
# ![Screenshot 2023-05-23 222220.png](data:image/png;base64,...)

# %% [markdown]
# **Type of error?** Operational error is one of the least common error I made during my testing phase.
#
# **Where is the error?** As can be seen in appendix 3, I put an "=" sign after "SELECT" which lead to this errror. The correct way is to put "*" sign.
#
# **How did I overcome it?** As it was one of my least common mistake, It was not really that hard to spot and The error popup display exactly where the error is, so it was quite easy to correct it.

# %% [markdown]
# ###Attribute Error

# %% [markdown]
# **Appendix 4**
# ![Screenshot 2023-05-23 222257.png](data:image/png;base64,...)

# %% [markdown]
# **Type of error?** Attibute Error was a very silly mistake on my end. This is the least type of error I got during my testing phase. This is the one and only snapshot of attribute error I came across.
#
# **Where is the error?** As can be seen in appendix 4, instead of writing "sns.lineplot", I wrote "sns.lineplo". It was an honest mistake on my behalf. This error occurs when there we enter a function that does not exist in a particular module we are running.
#
# **How did I overcome it?** The mistake seems a lot like a name error, it was easy to solve it. I just had to read my code 2 or 3 times to spot it.
